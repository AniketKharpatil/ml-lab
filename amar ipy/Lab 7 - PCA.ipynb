# %%
# !pip3 install matplotlib
# !pip3 install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# %matplotlib notebook

# %% [markdown]
# # PCA Example

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn import datasets

np.random.seed(0)

# %% [markdown]
# ## Generate/load data for regression

# %% [markdown]
# #### 1. Load datasets available in sklearn

# %%
from sklearn import datasets
X, y = datasets.load_iris(return_X_y=True)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d", elev=48, azim=134)
ax.set_position([0, 0, 0.95, 1])

plt.cla()
pca = PCA(n_components=3)
pca.fit(X)
X_pca = pca.transform(X)

for name, label in [("Setosa", 0), ("Versicolour", 1), ("Virginica", 2)]:
    ax.text3D(
        X[y == label, 0].mean(),
        X[y == label, 1].mean(),
        X[y == label, 2].mean(), name,
#         horizontalalignment="center",
        bbox=dict(alpha=0.5, edgecolor="w", facecolor="w"),
    )

# Plot data with colors matching the cluster predictions
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=np.choose(y, [1, 2, 0]).astype(float),
           cmap=plt.cm.jet, edgecolor="k")

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /var/folders/17/mm9y0nsx4njbtsk0rp6n1yn40000gr/T/ipykernel_4546/2703927397.py:23: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_ticklabels([])
# /var/folders/17/mm9y0nsx4njbtsk0rp6n1yn40000gr/T/ipykernel_4546/2703927397.py:24: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_ticklabels([])
# /var/folders/17/mm9y0nsx4njbtsk0rp6n1yn40000gr/T/ipykernel_4546/2703927397.py:25: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_ticklabels([])
